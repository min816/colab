# %% [markdown]
# <a href="https://colab.research.google.com/github/min816/colab/blob/main/%EC%88%98%ED%96%892.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Python"
change_text = text[0].lower() + text[1].upper() + text[2].upper() + text[3].upper() + text[4].upper() + text[5].upper()
print("원본 문자열은 ==>", text)
print("변환 문자열은 ==>", change_text)
# Out:
# 원본 문자열은 ==> Python
# 변환 문자열은 ==> pYTHON

# %%
text = "트와이스"
print("원본 문자열 ==>", text)
print("반대 문자열 ==>", end='')
print(text[3], end='')
print(text[2], end='')
print(text[1], end='')
print(text[0], end='')
# Out:
# 원본 문자열 ==> 트와이스
# 반대 문자열 ==>스이와트

# %%
text1 = input("첫번 째 문자열 ==>")
text2 = input("두번 째 문자열 ==>")

len1 = len(text1)
len2 = len(text2)

diff = len1 - len2

print("두 문자열의 길이 차이는", diff, "입니다.")
# Out:
# 첫번 째 문자열 ==>난생처음 파이썬
# 두번 째 문자열 ==>First Python
# 두 문자열의 길이 차이는 -4 입니다.

# %%
pound = int(input("파운드(lb)를 입력하세요:"))
kg = pound * 0.453592
print(pound, "파운드(lb)는", round(kg, 5), "킬로그램(kg)입니다.")

kg = int(input("킬로그램(kg)을 입력하세요 :"))
pound = kg * 2.204623
print(kg, "킬로그램(kg)은", round(pound, 5), "파운드(lb)입니다.")
# Out:
# 파운드(lb)를 입력하세요:15
# 15 파운드(lb)는 6.80388 킬로그램(kg)입니다.
# 킬로그램(kg)을 입력하세요 :15
# 15 킬로그램(kg)은 33.06935 파운드(lb)입니다.
